# %% [markdown]
# <a href="https://colab.research.google.com/github/divediamic530/Inventory-Management-ETG-/blob/main/Billing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# %%
import json
from datetime import datetime

#importing records from record.json
fd = open("record.json",'r')
r = fd.read()
fd.close()
fd = open("sales.json",'r')
s = fd.read()
fd.close()
#initialization of purchase dictionary  and loading data in record dictionary 
purchase = json.loads(s)
record = json.loads(r)
#showing the records available 
print('Products Available:')
record
# Out:
# Products Available:
# {'10001': {'exp': '06-03-2022',
#   'name': 'Amul Milk',
#   'pr': 60,
#   'prodt': 'Food',
#   'qn': 115},
#  '10002': {'exp': '01-09-2022',
#   'name': 'Tata Salt',
#   'pr': 18,
#   'prodt': 'Food',
#   'qn': 20},
#  '10003': {'exp': '06-06-2022',
#   'name': 'Amul Butter',
#   'pr': 230,
#   'prodt': 'Food',
#   'qn': 30},
#  '10004': {'exp': '06-06-2022',
#   'name': 'Duracell Aaa Batteries',
#   'pr': 148,
#   'prodt': 'Appliances',
#   'qn': 50},
#  '10005': {'exp': '06-06-2024',
#   'name': 'Usha Dry Iron',
#   'pr': 899,
#   'prodt': 'Appliances',
#   'qn': 8},
#  '10006': {'exp': '07-09-2024',
#   'name': 'Modular Trio 2pin',
#   'pr': 362,
#   'prodt': 'Appliances',
#   'qn': 13},
#  '10007': {'exp': '01-05-2023',
#   'name': 'Philips bulb',
#   'pr': 349,
#   'prodt': 'Electronic',
#   'qn': 90},
#  '10008': {'exp': '01-04-2022',
#   'name': 'Cheese Grater',
#   'pr': 47,
#   'prodt': 'Kitchen',
#   'qn': 10},
#  '10009': {'exp': '01-05-2022',
#   'name': 'Tea Stainer',
#   'pr': 55,
#   'prodt': 'Kitchen',
#   'qn': 10},
#  '10010': {'exp': '01-09-2023',
#   'name': 'Fruit Knife',
#   'pr': 80,
#   'prodt': 'Kitchen',
#   'qn': 10},
#  '10011': {'exp': '01-04-2023',
#   'name': 'Steel Forks',
#   'pr': 150,
#   'prodt': 'Kitchen',
#   'qn': 300},
#  '10012': {'exp': '01-04-2023',
#   'name': 'Steel Spoons',
#   'pr': 150,
#   'prodt': 'Kitchen',
#   'qn': 300},
#  '10013': {'exp': '15-03-2023',
#   'name': 'Sponge Scrub',
#   'pr': 65,
#   'prodt': 'Kitchen',
#   'qn': 200},
#  '10014': {'exp': '01-02-2022',
#   'name': 'Swash Card',
#   'pr': 18,
#   'prodt': 'Kitchen',
#   'qn': 150},
#  '10015': {'exp': '01-12-2022',
#   'name': 'Steel Scrub',
#   'pr': 40,
#   'prodt': 'Kitchen',
#   'qn': 30},
#  '10016': {'exp': '01-01-2023',
#   'name': 'Broom',
#   'pr': 150,
#   'prodt': 'HomeUtilities',
#   'qn': 10},
#  '10017': {'exp': '01-12-2023',
#   'name': 'Fry Pan',
#   'pr': 800,
#   'prodt': 'Kitchen',
#   'qn': 10},
#  '10018': {'exp': '20-09-2021',
#   'name': 'Bread',
#   'pr': 30,
#   'prodt': 'Food',
#   'qn': 9},
#  '10019': {'exp': '20-09-2021',
#   'name': 'Eggs',
#   'pr': 20,
#   'prodt': 'Food',
#   'qn': 900},
#  '10020': {'exp': '30-09-2021',
#   'name': 'Curd',
#   'pr': 90,
#   'prodt': 'Food',
#   'qn': 20},
#  '10021': {'exp': '10-10-2021',
#   'name': 'Dosa Batter',
#   'pr': 130,
#   'prodt': 'Food',
#   'qn': 15},
#  '10022': {'exp': '01-05-2022',
#   'name': 'Amul Ghee',
#   'pr': 350,
#   'prodt': 'Food',
#   'qn': 20},
#  '10023': {'exp': '01-12-2021',
#   'name': 'Red label Tea',
#   'pr': 275,
#   'prodt': 'Food',
#   'qn': 30},
#  '10024': {'exp': '01-11-2022',
#   'name': 'Nescafe Coffee',
#   'pr': 130,
#   'prodt': 'Food',
#   'qn': 40},
#  '10026': {'exp': '01-08-2022',
#   'name': 'Sprite',
#   'pr': 70,
#   'prodt': 'Drinks',
#   'qn': 30},
#  '10027': {'exp': '01-04-2022',
#   'name': 'Hersheys Chocolate',
#   'pr': 210,
#   'prodt': 'Drinks',
#   'qn': 20},
#  '10028': {'exp': '01-03-2022',
#   'name': 'Toast',
#   'pr': 30,
#   'prodt': 'Food',
#   'qn': 40},
#  '10029': {'exp': '01-01-2022',
#   'name': 'Kissan Ketchup',
#   'pr': 84,
#   'prodt': 'Food',
#   'qn': 45},
#  '10030': {'exp': '01-05-2022',
#   'name': 'Maggie',
#   'pr': 90,
#   'prodt': 'Food',
#   'qn': 25},
#  '10031': {'exp': '01-10-2021',
#   'name': 'Fruit Cake',
#   'pr': 150,
#   'prodt': 'Food',
#   'qn': 10},
#  '10032': {'exp': '01-10-2021',
#   'name': 'Chocolate Cake',
#   'pr': 150,
#   'prodt': 'Food',
#   'qn': 20},
#  '10033': {'exp': '01-11-2022',
#   'name': 'Hide and Seek',
#   'pr': 35,
#   'prodt': 'Biscuits',
#   'qn': 40},
#  '10034': {'exp': '01-12-2022',
#   'name': 'Good Day',
#   'pr': 35,
#   'prodt': 'Biscuits',
#   'qn': 40},
#  '10035': {'exp': '01-01-2023',
#   'name': 'Black Pepper',
#   'pr': 105,
#   'prodt': 'Food',
#   'qn': 50},
#  '10036': {'exp': '20-09-2022',
#   'name': 'Apple',
#   'pr': 150,
#   'prodt': 'Fruits',
#   'qn': 48},
#  '10037': {'exp': '20-09-2021',
#   'name': 'Peru',
#   'pr': 45,
#   'prodt': 'Fruits',
#   'qn': 40},
#  '10038': {'exp': '01-10-2021',
#   'name': 'Coconut',
#   'pr': 30,
#   'prodt': 'Fruits',
#   'qn': 5},
#  '10039': {'exp': '15-09-2021',
#   'name': 'Banana',
#   'pr': 60,
#   'prodt': 'Fruits',
#   'qn': 120}}

# %%
record
# Out:
# {'10001': {'exp': '06-03-2022',
#   'name': 'Amul Milk',
#   'pr': 60,
#   'prodt': 'Food',
#   'qn': 115},
#  '10002': {'exp': '01-09-2022',
#   'name': 'Tata Salt',
#   'pr': 18,
#   'prodt': 'Food',
#   'qn': 20},
#  '10003': {'exp': '06-06-2022',
#   'name': 'Amul Butter',
#   'pr': 230,
#   'prodt': 'Food',
#   'qn': 30},
#  '10004': {'exp': '06-06-2022',
#   'name': 'Duracell Aaa Batteries',
#   'pr': 148,
#   'prodt': 'Appliances',
#   'qn': 50},
#  '10005': {'exp': '06-06-2024',
#   'name': 'Usha Dry Iron',
#   'pr': 899,
#   'prodt': 'Appliances',
#   'qn': 8},
#  '10006': {'exp': '07-09-2024',
#   'name': 'Modular Trio 2pin',
#   'pr': 362,
#   'prodt': 'Appliances',
#   'qn': 13},
#  '10007': {'exp': '01-05-2023',
#   'name': 'Philips bulb',
#   'pr': 349,
#   'prodt': 'Electronic',
#   'qn': 90},
#  '10008': {'exp': '01-04-2022',
#   'name': 'Cheese Grater',
#   'pr': 47,
#   'prodt': 'Kitchen',
#   'qn': 10},
#  '10009': {'exp': '01-05-2022',
#   'name': 'Tea Stainer',
#   'pr': 55,
#   'prodt': 'Kitchen',
#   'qn': 10},
#  '10010': {'exp': '01-09-2023',
#   'name': 'Fruit Knife',
#   'pr': 80,
#   'prodt': 'Kitchen',
#   'qn': 10},
#  '10011': {'exp': '01-04-2023',
#   'name': 'Steel Forks',
#   'pr': 150,
#   'prodt': 'Kitchen',
#   'qn': 300},
#  '10012': {'exp': '01-04-2023',
#   'name': 'Steel Spoons',
#   'pr': 150,
#   'prodt': 'Kitchen',
#   'qn': 300},
#  '10013': {'exp': '15-03-2023',
#   'name': 'Sponge Scrub',
#   'pr': 65,
#   'prodt': 'Kitchen',
#   'qn': 200},
#  '10014': {'exp': '01-02-2022',
#   'name': 'Swash Card',
#   'pr': 18,
#   'prodt': 'Kitchen',
#   'qn': 150},
#  '10015': {'exp': '01-12-2022',
#   'name': 'Steel Scrub',
#   'pr': 40,
#   'prodt': 'Kitchen',
#   'qn': 30},
#  '10016': {'exp': '01-01-2023',
#   'name': 'Broom',
#   'pr': 150,
#   'prodt': 'HomeUtilities',
#   'qn': 10},
#  '10017': {'exp': '01-12-2023',
#   'name': 'Fry Pan',
#   'pr': 800,
#   'prodt': 'Kitchen',
#   'qn': 10},
#  '10018': {'exp': '20-09-2021',
#   'name': 'Bread',
#   'pr': 30,
#   'prodt': 'Food',
#   'qn': 9},
#  '10019': {'exp': '20-09-2021',
#   'name': 'Eggs',
#   'pr': 20,
#   'prodt': 'Food',
#   'qn': 900},
#  '10020': {'exp': '30-09-2021',
#   'name': 'Curd',
#   'pr': 90,
#   'prodt': 'Food',
#   'qn': 20},
#  '10021': {'exp': '10-10-2021',
#   'name': 'Dosa Batter',
#   'pr': 130,
#   'prodt': 'Food',
#   'qn': 15},
#  '10022': {'exp': '01-05-2022',
#   'name': 'Amul Ghee',
#   'pr': 350,
#   'prodt': 'Food',
#   'qn': 20},
#  '10023': {'exp': '01-12-2021',
#   'name': 'Red label Tea',
#   'pr': 275,
#   'prodt': 'Food',
#   'qn': 30},
#  '10024': {'exp': '01-11-2022',
#   'name': 'Nescafe Coffee',
#   'pr': 130,
#   'prodt': 'Food',
#   'qn': 40},
#  '10026': {'exp': '01-08-2022',
#   'name': 'Sprite',
#   'pr': 70,
#   'prodt': 'Drinks',
#   'qn': 30},
#  '10027': {'exp': '01-04-2022',
#   'name': 'Hersheys Chocolate',
#   'pr': 210,
#   'prodt': 'Drinks',
#   'qn': 20},
#  '10028': {'exp': '01-03-2022',
#   'name': 'Toast',
#   'pr': 30,
#   'prodt': 'Food',
#   'qn': 40},
#  '10029': {'exp': '01-01-2022',
#   'name': 'Kissan Ketchup',
#   'pr': 84,
#   'prodt': 'Food',
#   'qn': 45},
#  '10030': {'exp': '01-05-2022',
#   'name': 'Maggie',
#   'pr': 90,
#   'prodt': 'Food',
#   'qn': 25},
#  '10031': {'exp': '01-10-2021',
#   'name': 'Fruit Cake',
#   'pr': 150,
#   'prodt': 'Food',
#   'qn': 10},
#  '10032': {'exp': '01-10-2021',
#   'name': 'Chocolate Cake',
#   'pr': 150,
#   'prodt': 'Food',
#   'qn': 20},
#  '10033': {'exp': '01-11-2022',
#   'name': 'Hide and Seek',
#   'pr': 35,
#   'prodt': 'Biscuits',
#   'qn': 40},
#  '10034': {'exp': '01-12-2022',
#   'name': 'Good Day',
#   'pr': 35,
#   'prodt': 'Biscuits',
#   'qn': 40},
#  '10035': {'exp': '01-01-2023',
#   'name': 'Black Pepper',
#   'pr': 105,
#   'prodt': 'Food',
#   'qn': 50},
#  '10036': {'exp': '20-09-2022',
#   'name': 'Apple',
#   'pr': 150,
#   'prodt': 'Fruits',
#   'qn': 48},
#  '10037': {'exp': '20-09-2021',
#   'name': 'Peru',
#   'pr': 45,
#   'prodt': 'Fruits',
#   'qn': 40},
#  '10038': {'exp': '01-10-2021',
#   'name': 'Coconut',
#   'pr': 30,
#   'prodt': 'Fruits',
#   'qn': 5},
#  '10039': {'exp': '15-09-2021',
#   'name': 'Banana',
#   'pr': 60,
#   'prodt': 'Fruits',
#   'qn': 120}}

# %%
cname = str(input("Enter your name: "))
now = datetime.now() 
dt_string = now.strftime("%d/%m/%Y %H:%M")
billno = "Bill"+now.strftime("%y%m%d%H%M%S")
#While loop is used if the customer wants to purchase more items
while True:
  ui_prod  = str(input("Enter the product_Id: "))
  ui_quant = int(input("Enter the quantity: "))
  
  #Checking if the enter product id is available inside record dictionary
  if ui_prod in record:  
    
    #checking if the records have quantity requested by the customer
    if record[ui_prod]['qn']>= ui_quant:
      #Displaying the data of the selected records
      print("**********************************")
      print("Product: ", record[ui_prod]['name'])
      print("Price: ", record[ui_prod]['pr'])
      print("Product Type: ", record[ui_prod]['prodt'])
      print("Expiry Date: ", record[ui_prod]['exp'])
      print("Billing Amount: ", record[ui_prod]['pr'] * ui_quant)
      print("**********************************")
      
      #inserting into purchased items into purchase dictionary
      now = datetime.now() 
      dt_string = now.strftime("%d/%m/%Y %H:%M")
      trans_id = "T"+now.strftime("%y%m%d%H%M%S")
      purchase[trans_id] = {'Bill_id':billno,
                            'prod_id':ui_prod,
                            'cust_name':cname,
                            'prod_name': record[ui_prod]['name'],
                            'pr':record[ui_prod]['pr'],
                            'prodt':record[ui_prod]['prodt'],
                            'qn': ui_quant, 
                            'date':dt_string,
                            'amount':record[ui_prod]['pr'] * ui_quant}
      #Subtracting the quantity purchased by the customer
      record[ui_prod]['qn'] = int(record[ui_prod]['qn']) - int(ui_quant)
    #if the quantity requested by the user exceeds the records quantity
    else:
      print("We dont not have such quantity for the product you want.")
  
  #if the entered product id is not available inside record dictionary
  else:
    print("Please enter the proper product_ID as requested doesnt exist")
    print("**********************************")
    
  #Checking if the customer wants to buy more products
  choice = input('Do you want to continue? Y/N : ')
  if choice =='N':
    break
  else:
    continue
# Out:
# Enter your name: Aditya Divedi
# Enter the product_Id: 10009
# Enter the quantity: 35
# We dont not have such quantity for the product you want.
# Do you want to continue? Y/N : y
# Enter the product_Id: 10031
# Enter the quantity: 5
# **********************************
# Product:  Fruit Cake
# Price:  150
# Product Type:  Food
# Expiry Date:  01-10-2021
# Billing Amount:  750
# **********************************
# Do you want to continue? Y/N : n
# Enter the product_Id: 10032
# Enter the quantity: 2
# **********************************
# Product:  Chocolate Cake
# Price:  150
# Product Type:  Food
# Expiry Date:  01-10-2021
# Billing Amount:  300
# **********************************
# Do you want to continue? Y/N : N

# %%
for key in purchase:
  if billno == purchase[key]['Bill_id']:
    print(purchase[key])
# Out:
# {'Bill_id': 'Bill210906150407', 'prod_id': '10031', 'cust_name': 'Aditya Divedi', 'prod_name': 'Fruit Cake', 'pr': 150, 'prodt': 'Food', 'qn': 5, 'date': '06/09/2021 15:04', 'amount': 750}
# {'Bill_id': 'Bill210906150407', 'prod_id': '10032', 'cust_name': 'Aditya Divedi', 'prod_name': 'Chocolate Cake', 'pr': 150, 'prodt': 'Food', 'qn': 2, 'date': '06/09/2021 15:05', 'amount': 300}

# %%
while True:
  chc = str(input("Do you want to confirm this order Y/N: "))
  if chc =='Y':
    break
  else:
    chan = input("1. Remove an Item 2. Edit qty of an item: ")
    trid = str(input("Transaction Id which you want to edit or remove: "))
    if trid in purchase:
      if chan == '1':
        del purchase[trid]
      elif chan == '2':
        nqty = int(input("Enter the quantity you want: "))
        if nqty <=record[ui_prod]['qn']:
          prod_id = purchase[trans_id]['prod_id']
          record[prod_id]['qn'] += int(purchase[trans_id]['qn'])
          purchase[trans_id]['qn'] = int(nqty)
          record[prod_id]['qn'] -= int(purchase[trans_id]['qn'])
          purchase[trans_id]['amount'] = int(nqty) * purchase[trans_id]['pr']
        else:
          print("We dont not have such quantity for the product you want.")
    else:
      print("Wrong Transaction id entered")
  continue
# Out:
# Do you want to confirm this order Y/N: Y

# %%
for key in purchase:
  prod_id = purchase[key]['prod_id']
  #if the quantity has reached 0 after subtraction the product will be deleted
  if int(record[prod_id]['qn']) == 0:
    del record[prod_id]

# %%
print("Your final bill is")
print("**********************************************")
print("Customer Name : ",cname )
print("Bill Number : ", billno)
print("**********************************************")
print("Product\t\tPrice\tQauntity\tTotal")
grandtotal = 0
for key in purchase:
  if billno == purchase[key]['Bill_id']:
    print(str(purchase[key]['prod_name'])+"\t"
    +str(purchase[key]['pr'])+"\t"
    +str(purchase[key]['qn'])+"\t\t"
    +str(purchase[key]['amount']))
    grandtotal += int(purchase[key]['amount'])
print("**********************************************")
print("Your Grand Total = "+str(grandtotal))
print("~~~~~~~~~~~~~~~~Thank You Please Visit Again~~~~~~~~~~~~~~~~")
# Out:
# Your final bill is
# **********************************************
# Customer Name :  Aditya Divedi
# Bill Number :  Bill210906150407
# **********************************************
# Product		Price	Qauntity	Total
# Fruit Cake	150	5		750
# Chocolate Cake	150	2		300
# **********************************************
# Your Grand Total = 1050
# ~~~~~~~~~~~~~~~~Thank You Please Visit Again~~~~~~~~~~~~~~~~

# %%
js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()

jss = json.dumps(purchase)
fd = open("sales.json",'w')
fd.write(jss)
fd.close()
